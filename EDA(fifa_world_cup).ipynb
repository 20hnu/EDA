# %% [markdown]
# <a href="https://colab.research.google.com/github/20hnu/EDA/blob/main/EDA(fifa_world_cup).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as ps

# %%
world_ranking = pd.read_csv("/content/drive/MyDrive/EDA/fifa_ranking_2022-10-06 - fifa_ranking_2022-10-06.csv.csv")

# %%
matches = pd.read_csv("/content/drive/MyDrive/EDA/matches_1930_2022 - matches_1930_2022.csv.csv")
world_cup = pd.read_csv("/content/drive/MyDrive/EDA/world_cup - world_cup.csv.csv")

# %%
world_cup.head(5)
# Out:
#    Year          Host  Teams   Champion    Runner-Up  \
# 0  2022         Qatar     32  Argentina       France
# 1  2018        Russia     32     France      Croatia
# 2  2014        Brazil     32    Germany    Argentina
# 3  2010  South Africa     32      Spain  Netherlands
# 4  2006       Germany     32      Italy       France
#
#                               TopScorrer  Attendance  AttendanceAvg  Matches
# 0                      Kylian Mbappé - 8     3404252          53191       64
# 1                         Harry Kane - 6     3031768          47371       64
# 2                    James Rodríguez - 6     3429873          53592       64
# 3  Wesley Sneijder, Thomas Müller... - 5     3178856          49670       64
# 4                     Miroslav Klose - 5     3352605          52384       64

# %%
matches.sample(5)
# Out:
#        home_team   away_team  home_score  home_xg  home_penalty  away_score  \
# 626        Italy    Cameroon           1      NaN           NaN           1
# 79       Uruguay    Portugal           2      0.6           NaN           1
# 303        Spain     Ukraine           4      NaN           NaN           0
# 133  Netherlands  Costa Rica           0      NaN           4.0           0
# 878       Brazil  Yugoslavia           1      NaN           NaN           1
#
#      away_xg  away_penalty    home_manager home_captain  ...  \
# 626      NaN           NaN    Enzo Bearzot    Dino Zoff  ...
# 79       1.0           NaN   Óscar Tabárez  Diego Godín  ...
# 303      NaN           NaN   Luis Aragonés          NaN  ...
# 133      NaN           3.0  Louis van Gaal          NaN  ...
# 878      NaN           NaN    Zeze Moreira        Bauer  ...
#
#     home_penalty_shootout_miss_long  \
# 626                             NaN
# 79                              NaN
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        964 non-null    object
#  1   away_team                        964 non-null    object
#  2   home_score                       964 non-null    int64
#  3   home_xg                          128 non-null    float64
#  4   home_penalty                     35 non-null     float64
#  5   away_score                       964 non-null    int64
#  6   away_xg                          128 non-null    float64
#  7   away_penalty                     35 non-null     float64
#  8   home_manager                     964 non-null    object
#  9   home_captain                     644 non-null    object
#  10  away_manager                     964 non-null    object
#  11  away_captain                     644 non-null    object
# ...

# %%
matches['home_goal_long'][0]
# Out:
# "['36&rsquor;|2:0|Ángel Di María|Assist:|Alexis Mac Allister', '108&rsquor;|3:2|Lionel Messi']"

# %%
print(matches.shape)
print(world_cup.shape)
print(world_ranking.shape)
# Out:
# (964, 44)
# (22, 9)
# (211, 7)

# %%
(matches.isna().sum())/(matches.shape[0])*100
# Out:
# home_team                           0.000000
# away_team                           0.000000
# home_score                          0.000000
# home_xg                            86.721992
# home_penalty                       96.369295
# away_score                          0.000000
# away_xg                            86.721992
# away_penalty                       96.369295
# home_manager                        0.000000
# home_captain                       33.195021
# away_manager                        0.000000
# away_captain                       33.195021
# Attendance                          0.000000
# Venue                               0.000000
# Officials                          26.452282
# Round                               0.000000
# Date                                0.000000
# Score                               0.000000
# Referee                            26.452282
# Notes                              92.427386
# Host                                0.000000
# ...

# %%
world_cup.isna().sum()
# Out:
# Year             0
# Host             0
# Teams            0
# Champion         0
# Runner-Up        0
# TopScorrer       0
# Attendance       0
# AttendanceAvg    0
# Matches          0
# dtype: int64

# %%
world_ranking.isna().sum()
# Out:
# team               0
# team_code          0
# association        0
# rank               0
# previous_rank      0
# points             0
# previous_points    0
# dtype: int64

# %%
print(matches.duplicated().sum())
print(world_cup.duplicated().sum())
print(world_ranking.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
matches['home_team'].unique()
# Out:
# array(['Argentina', 'Croatia', 'France', 'Morocco', 'England',
#        'Netherlands', 'Portugal', 'Japan', 'Brazil', 'Korea Republic',
#        'Ghana', 'Cameroon', 'Serbia', 'Canada', 'Costa Rica', 'Australia',
#        'Tunisia', 'Saudi Arabia', 'Poland', 'Ecuador', 'IR Iran', 'Wales',
#        'Belgium', 'Spain', 'Qatar', 'Switzerland', 'Uruguay', 'Germany',
#        'Denmark', 'Mexico', 'Senegal', 'United States', 'Sweden',
#        'Russia', 'Colombia', 'Panama', 'Iceland', 'Nigeria', 'Peru',
#        'Egypt', 'Algeria', 'Bosnia and Herzegovina', 'Honduras', 'Italy',
#        'Greece', "Côte d'Ivoire", 'Chile', 'Paraguay', 'Korea DPR',
#        'Slovakia', 'Slovenia', 'South Africa', 'New Zealand', 'Ukraine',
#        'Togo', 'Czech Republic', 'Serbia and Montenegro', 'Angola',
#        'Trinidad and Tobago', 'Türkiye', 'China PR',
#        'Republic of Ireland', 'Romania', 'Scotland', 'FR Yugoslavia',
#        'Jamaica', 'Bulgaria', 'Bolivia', 'Norway', 'West Germany',
# ...

# %%
matches['away_team'].unique()
# Out:
# array(['France', 'Morocco', 'Croatia', 'Portugal', 'Brazil', 'Argentina',
#        'Spain', 'Switzerland', 'Korea Republic', 'Poland', 'Senegal',
#        'United States', 'Australia', 'Uruguay', 'Belgium', 'Germany',
#        'Denmark', 'Mexico', 'Qatar', 'England', 'Serbia', 'Ghana',
#        'Costa Rica', 'Canada', 'Saudi Arabia', 'IR Iran', 'Ecuador',
#        'Cameroon', 'Japan', 'Tunisia', 'Netherlands', 'Wales', 'Russia',
#        'Colombia', 'Sweden', 'Peru', 'Egypt', 'Panama', 'Iceland',
#        'Nigeria', 'Algeria', 'Greece', 'Chile', "Côte d'Ivoire",
#        'Bosnia and Herzegovina', 'Honduras', 'Italy', 'Slovakia',
#        'New Zealand', 'South Africa', 'Korea DPR', 'Paraguay', 'Slovenia',
#        'Ukraine', 'Angola', 'Serbia and Montenegro',
#        'Trinidad and Tobago', 'Togo', 'Czech Republic', 'Türkiye',
#        'Republic of Ireland', 'China PR', 'FR Yugoslavia', 'Norway',
#        'Jamaica', 'Bulgaria', 'Austria', 'Scotland', 'Romania', 'Bolivia',
# ...

# %%
matches["home_team"]=matches["home_team"].apply(lambda x: x.replace("Germany DR", "West Germany"))
matches["away_team"]=matches["away_team"].apply(lambda x: x.replace("Germany DR", "West Germany"))

# %% [markdown]
# ####EDA

# %%
print("total number of matches: ", len(matches))
print("total number of teams: ", len(matches["home_team"].unique()))
print("total goal scored: ", matches["home_score"].sum()+matches["away_score"].sum())
print("Average goal scored permatch:", (matches["home_score"].sum()+matches["away_score"].sum())/len(matches))
print("total attendance: ", matches["Attendance"].sum())
# Out:
# total number of matches:  964
# total number of teams:  81
# total goal scored:  2720
# Average goal scored permatch: 2.8215767634854774
# total attendance:  44048413

# %%
world_cup.columns
# Out:
# Index(['Year', 'Host', 'Teams', 'Champion', 'Runner-Up', 'TopScorrer',
#        'Attendance', 'AttendanceAvg', 'Matches'],
#       dtype='object')

# %%
# country that is winner and runner-up
winner = world_cup["Champion"].value_counts().reset_index()

# %%
runner_up = world_cup["Runner-Up"].value_counts().reset_index()

# %%
runner_up
# Out:
#          Runner-Up  count
# 0        Argentina      3
# 1      Netherlands      3
# 2     West Germany      3
# 3           France      2
# 4           Brazil      2
# 5            Italy      2
# 6   Czechoslovakia      2
# 7          Hungary      2
# 8          Croatia      1
# 9          Germany      1
# 10          Sweden      1

# %%
fig = ps.pie(winner, values='count', names='Champion', title='Winner of World Cup (no of times)')
fig.update_traces(textinfo="label+value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
matches["Round"].unique()
# Out:
# array(['Final', 'Third-place match', 'Semi-finals', 'Quarter-finals',
#        'Round of 16', 'Group stage', 'Second group stage',
#        'First group stage', 'Second round', 'First round',
#        'Group stage play-off', 'Final stage'], dtype=object)

# %%
matches["home_penalty"].fillna(0, inplace=True)
matches["away_penalty"].fillna(0, inplace=True)
# Out:
# <ipython-input-24-d9476cd63bb0>:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# <ipython-input-24-d9476cd63bb0>:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
matches["h_total"] = matches["home_score"]+ matches["home_penalty"]
matches["a_total"] = matches["away_score"]+ matches["away_penalty"]

# %%
second_runner_up_df = matches[matches["Round"] == 'Third-place match']

# %%
second_runner_up_series = second_runner_up_df.apply(lambda x: x["away_team"] if x["a_total"] > x["h_total"] else x["home_team"], axis=1)

# %%
second_runner_up_series.value_counts()
# Out:
# Germany         3
# Croatia         2
# France          2
# Poland          2
# Brazil          2
# Belgium         1
# Netherlands     1
# Türkiye         1
# Sweden          1
# Italy           1
# West Germany    1
# Portugal        1
# Chile           1
# Austria         1
# Name: count, dtype: int64

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
trace1 = go.Bar(
    x=second_runner_up_series.value_counts().index,
    y=second_runner_up_series.value_counts().values,
    name='Second Runner-Up'
)
trace2 = go.Bar(
    x=runner_up['Runner-Up'],
    y=runner_up['count'],
    name='Runner-Up'
)

# %%
fig = make_subplots(rows=1, cols=2, subplot_titles=('Runner-Up','Second Runner-Up'))
fig.add_trace(trace2, row=1, col=1)
fig.add_trace(trace1, row=1, col=2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##CONCLUSION
#
# * Brazil won the most number of titles followed by Italy and Argentina.
#
# * Argentina, Netherland and West Germany won the most number of Runner Up title.
#
# * Germany was the second runner up for most of the times.

# %%
# In which year a particular team participated
data = matches.groupby("Year").agg(home=("home_team",list),away = ("away_team",list))
data
# Out:
#                                                    home  \
# Year
# 1930  [Uruguay, Uruguay, Argentina, Argentina, Urugu...
# 1934  [Italy, Germany, Czechoslovakia, Italy, Italy,...
# 1938  [Brazil, Italy, Hungary, Italy, Brazil, Sweden...
# 1950  [Sweden, Uruguay, Brazil, Uruguay, Brazil, Uru...
# 1954  [Germany, Austria, Hungary, Germany, Germany, ...
# 1958  [Brazil, France, Sweden, Brazil, France, West ...
# 1962  [Brazil, Chile, Brazil, Czechoslovakia, Chile,...
# 1966  [England, Portugal, England, West Germany, Por...
# 1970  [Brazil, West Germany, Italy, Brazil, Brazil, ...
# 1974  [Netherlands, Brazil, Poland, Netherlands, Arg...
# 1978  [Argentina, Brazil, Netherlands, Austria, Braz...
# 1982  [Italy, Poland, Poland, West Germany, Italy, S...
# 1986  [Argentina, France, France, Argentina, Argenti...
# 1990  [West Germany, Italy, West Germany, Italy, Wes...
# 1994  [Brazil, Sweden, Bulgaria, Sweden, Bulgaria, R...
# 1998  [Brazil, Netherlands, France, Brazil, Netherla...
# ...

# %%
data["teams"] = data.apply(lambda x: list(set(x["home"] + x["away"])), axis=1)

# %%
data["teams"]
# Out:
# Year
# 1930    [Uruguay, Paraguay, Belgium, Peru, Yugoslavia,...
# 1934    [Switzerland, Spain, Hungary, Egypt, Germany, ...
# 1938    [Switzerland, Hungary, Germany, Poland, Italy,...
# 1950    [Switzerland, Spain, England, Uruguay, Paragua...
# 1954    [Switzerland, Türkiye, England, Uruguay, Hunga...
# 1958    [Northern Ireland, England, Paraguay, Wales, H...
# 1962    [Switzerland, Spain, England, Uruguay, Hungary...
# 1966    [Portugal, Switzerland, Spain, England, Urugua...
# 1970    [England, Uruguay, Bulgaria, Italy, Sweden, So...
# 1974    [Haiti, Uruguay, Poland, Bulgaria, Sweden, Aus...
# 1978    [IR Iran, Spain, Tunisia, Hungary, Poland, Ita...
# 1982    [Cameroon, England, Soviet Union, Brazil, Arge...
# 1986    [England, Paraguay, Soviet Union, Canada, Braz...
# 1990    [Cameroon, England, Soviet Union, Brazil, Arge...
# 1994    [Switzerland, Cameroon, Brazil, Argentina, Ita...
# 1998    [Cameroon, England, Paraguay, FR Yugoslavia, B...
# ...

# %%
def count(row):
  return len(row)

# %%
data["no. of teams"] = data["teams"].apply(count)

# %%
data
# Out:
#                                                    home  \
# Year
# 1930  [Uruguay, Uruguay, Argentina, Argentina, Urugu...
# 1934  [Italy, Germany, Czechoslovakia, Italy, Italy,...
# 1938  [Brazil, Italy, Hungary, Italy, Brazil, Sweden...
# 1950  [Sweden, Uruguay, Brazil, Uruguay, Brazil, Uru...
# 1954  [Germany, Austria, Hungary, Germany, Germany, ...
# 1958  [Brazil, France, Sweden, Brazil, France, West ...
# 1962  [Brazil, Chile, Brazil, Czechoslovakia, Chile,...
# 1966  [England, Portugal, England, West Germany, Por...
# 1970  [Brazil, West Germany, Italy, Brazil, Brazil, ...
# 1974  [Netherlands, Brazil, Poland, Netherlands, Arg...
# 1978  [Argentina, Brazil, Netherlands, Austria, Braz...
# 1982  [Italy, Poland, Poland, West Germany, Italy, S...
# 1986  [Argentina, France, France, Argentina, Argenti...
# 1990  [West Germany, Italy, West Germany, Italy, Wes...
# 1994  [Brazil, Sweden, Bulgaria, Sweden, Bulgaria, R...
# 1998  [Brazil, Netherlands, France, Brazil, Netherla...
# ...

# %%
data_pivot = data["teams"].explode().reset_index().pivot(index="Year", columns="teams", values="Year").fillna(0).T

# %%
data_pivot = data_pivot.map(lambda x: 1 if x>0 else 0)

# %%
plt.figure(figsize=(12,20))
sns.heatmap(data_pivot, cmap="Blues", linecolor="red", linewidths=1)
# Out:
# <Axes: xlabel='Year', ylabel='teams'>

# %% [markdown]
# ##OBSERVATIONS
#
# * Brazil is the only countryto play all editions of the FIFA cup.
#
# * Countries are Qatar, Canada, Wales are new to the tournament
#
# * Countries like Cuba, Isreal, Kuwait, Jamaica, Ukrain, Tongo etc. are participated in only 1 edition of FIFA.

# %%
world_ranking.head()
# Out:
#         team team_code association  rank  previous_rank   points  \
# 0     Brazil       BRA    CONMEBOL     1              1  1841.30
# 1    Belgium       BEL        UEFA     2              2  1816.71
# 2  Argentina       ARG    CONMEBOL     3              3  1773.88
# 3     France       FRA        UEFA     4              4  1759.78
# 4    England       ENG        UEFA     5              5  1728.47
#
#    previous_points
# 0          1837.56
# 1          1821.92
# 2          1770.65
# 3          1764.85
# 4          1737.46

# %%
world_ranking["rank_change"] = world_ranking["rank"] - world_ranking["previous_rank"]

# %%
def rank_change(row):
  if row["rank_change"] > 0:
    return "Decreased"
  elif row["rank_change"] < 0:
    return "Increased"
  else:
    return "No Change"

# %%
world_ranking["rank_change"] = world_ranking.apply(rank_change, axis=1)

# %%
world_ranking["rank_change"].value_counts()
# Out:
# rank_change
# Increased    77
# Decreased    68
# No Change    66
# Name: count, dtype: int64

# %%
world_ranking[world_ranking["team"] == "Nepal"]
# Out:
#       team team_code association  rank  previous_rank  points  \
# 174  Nepal       NEP         AFC   175            176  954.86
#
#      previous_points rank_change
# 174           950.45   Increased

# %%
same_rank = world_ranking[world_ranking["rank_change"] == "No Change"]["team"].tolist()
Rank_increased = world_ranking[world_ranking["rank_change"] == "Increased"]["team"].tolist()
Rank_decreased = world_ranking[world_ranking["rank_change"] == "Decreased"]["team"].tolist()

# %%
same_rank
# Out:
# ['Brazil',
#  'Belgium',
#  'Argentina',
#  'France',
#  'England',
#  'Netherlands',
#  'Portugal',
#  'Denmark',
#  'Germany',
#  'Colombia',
#  'Senegal',
#  'Wales',
#  'Japan',
#  'Poland',
#  'Ukraine',
#  'Korea Republic',
#  'Chile',
#  'Tunisia',
#  'Ecuador',
#  'Mali',
#  'Albania',
#  'Oman',
#  'Israel',
#  'Uzbekistan',
#  'Honduras',
#  'Guinea',
#  'Bahrain',
#  'Benin',
#  'Palestine',
#  'Kyrgyz Republic',
#  'Equatorial Guinea',
#  'Thailand',
#  'Korea DPR',
#  'Guatemala',
#  'Turkmenistan',
#  'Ethiopia',
#  'St Kitts and Nevis',
#  'Burundi',
#  'Kuwait',
#  'Liberia',
#  'Chinese Taipei',
#  'Myanmar',
#  'Tahiti',
#  'Fiji',
#  'Vanuatu',
#  'South Sudan',
#  'Barbados',
#  'Cuba',
#  'Puerto Rico',
#  'Mauritius',
#  'Chad',
#  'Macau',
#  'American Samoa',
#  'Cook Islands',
#  'Brunei Darussalam',
#  'Samoa',
#  'Bangladesh',
#  'Djibouti',
#  'Tonga',
#  'Guam',
#  'Turks and Caicos Islands',
#  'Sri Lanka',
#  'US Virgin Islands',
# ...

# %%
max_len = max(len(same_rank), len(Rank_increased), len(Rank_decreased))

# %%
same_rank += [''] * (max_len - len(same_rank))
Rank_increased += [''] * (max_len - len(Rank_increased))
Rank_decreased += [''] * (max_len - len(Rank_decreased))

# %%
rank_dataframe = pd.DataFrame({
    'Same Rank': same_rank,
    'Rank Increased': Rank_increased,
    'Rank Decreased': Rank_decreased
})

# %%
rank_dataframe
# Out:
#     Same Rank Rank Increased Rank Decreased
# 0      Brazil          Italy          Spain
# 1     Belgium        Croatia         Mexico
# 2   Argentina    Switzerland        Uruguay
# 3      France        IR Iran            USA
# 4     England         Serbia           Peru
# ..        ...            ...            ...
# 72               Timor-Leste
# 73                   Eritrea
# 74                     Aruba
# 75                   Bahamas
# 76                   Somalia
#
# [77 rows x 3 columns]

# %%
def find_rank(country):
  result = []
  rank = world_ranking[world_ranking["team"] == country]["rank"].values[0]
  result.append(rank)
  for column in rank_dataframe.columns:
    if country in rank_dataframe[column].values:
      result.append(column)
  return result

# %%
find_rank("Nepal")
# Out:
# [175, 'Rank Increased']

# %% [markdown]
# ###Advance EDA

# %%
#probability of a tram winning knockout matches

# %%
def get_win_percent(country):
  data = matches[((matches["home_team"] == country) | (matches["away_team"] == country))
  & ((matches["Round"] == "Final") | (matches["Round"] == "Semi-finals") | (matches["Round"] == "Quarter-finals"))]


  df1 = data["Round"].value_counts().reset_index()
  df1.columns=["Round","Total Matches"]

  def get_winner(row):
    if row["h_total"] > row["a_total"]:
      return row["home_team"]
    else:
      return row["away_team"]

  data["winner"] = data.apply(get_winner, axis=1)

  df2 = data[data["winner"] == country]["Round"].value_counts().reset_index()
  df2.columns = ["Round","Winner"]

  df = pd.merge(df1,df2,on="Round")

  df["Win %"] = round(df["Winner"]/df["Total Matches"]*100,2)

  return df

# %%
get_win_percent("Korea Republic")
# Out:
# <ipython-input-56-ba7bb15b3141>:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Round  Total Matches  Winner  Win %
# 0  Quarter-finals              1       1  100.0

# %%
#checking playing strategy of teams in knockout v/s non-knockout matches

# %%
matches["away_goal"][0]
# Out:
# 'Kylian Mbappé · 81'

# %%
import re

# %%
pattern = r'\b(\d+)\b'

# %%
#function to extract time form each row
def extract_time(row,name):
  if pd.notna(row[name]):
    goal_str = str(row[name])
    times=[]
    matches = re.findall(pattern, goal_str)
    times.extend(matches)
    return ' '.join(times)
  else:
    return ' '

# %%
matches["home_goal_time"] = matches.apply(extract_time, name="home_goal",axis=1)

# %%
matches["home_goal_time"]
# Out:
# 0           36 108
# 1             7 42
# 2             5 79
# 3            39 69
# 4               42
#           ...
# 959             81
# 960          21 30
# 961        1 79 89
# 962       23 45 69
# 963    19 40 43 87
# Name: home_goal_time, Length: 964, dtype: object

# %%
matches["away_goal_time"] = matches.apply(extract_time, name="away_goal",axis=1)

# %%
matches["away_goal_time"]
# Out:
# 0      81
# 1       9
# 2
# 3
# 4
#        ..
# 959
# 960    62
# 961    75
# 962
# 963    70
# Name: away_goal_time, Length: 964, dtype: object

# %%
knockout_rounds = ["Final","Semi-finals","Quarter-finals"]
matches["Knockout"] = matches["Round"].apply(lambda x: "Knockout" if x in knockout_rounds else "Not Knockout")

# %%
matches["Knockout"]
# Out:
# 0          Knockout
# 1      Not Knockout
# 2          Knockout
# 3          Knockout
# 4          Knockout
#            ...
# 959    Not Knockout
# 960    Not Knockout
# 961    Not Knockout
# 962    Not Knockout
# 963    Not Knockout
# Name: Knockout, Length: 964, dtype: object

# %%
country="Canada"

# %%
home_knockout = matches[(matches["home_team"] ==  country)& (matches["Knockout"] == "Knockout")]
away_knockout = matches[(matches["away_team"] ==  country)& (matches["Knockout"] == "Knockout")]

home_notknockout = matches[(matches["home_team"] ==  country)& (matches["Knockout"] == "Not Knockout")]
away_notknockout = matches[(matches["away_team"] ==  country)& (matches["Knockout"] == "Not Knockout")]

# %%
#for knockout matches

a = home_knockout["home_goal_time"].str.split(' ').explode().reset_index()
b = away_knockout["away_goal_time"].str.split(' ').explode().reset_index()

df3 = pd.concat([a,b],axis=0, ignore_index=True)
df3.replace(r'^\s*$',0,regex=True, inplace=True)
df3.fillna(0, inplace=True)

df3["home_goal_time"] = df3["home_goal_time"].astype(int)
df3["away_goal_time"] = df3["away_goal_time"].astype(int)

df3["time"] = df3["home_goal_time"] + df3["away_goal_time"]

def determine(row):
  if row["time"] <=45:
    return "First Half"
  elif row["time"] <=90:
    return "Second Half"
  else:
    return "Extra Time"


df3["time"] = df3.apply(determine,axis=1)

df3 = df3[df3["time"] != 0]

round(df3["time"].value_counts()/len(df3)*100, 2)
# Out:
# Series([], Name: count, dtype: float64)

# %%
#for non-knockout matches

a = home_notknockout["home_goal_time"].str.split(' ').explode().reset_index()
b = away_notknockout["away_goal_time"].str.split(' ').explode().reset_index()

df3 = pd.concat([a,b],axis=0, ignore_index=True)
df3.replace(r'^\s*$',0,regex=True, inplace=True)
df3.fillna(0, inplace=True)

df3["home_goal_time"] = df3["home_goal_time"].astype(int)
df3["away_goal_time"] = df3["away_goal_time"].astype(int)

df3["time"] = df3["home_goal_time"] + df3["away_goal_time"]

def determine(row):
  if row["time"] <=45:
    return "First Half"
  elif row["time"] <=90:
    return "Second Half"
  else:
    return "Extra Time"


df3["time"] = df3.apply(determine,axis=1)

df3 = df3[df3["time"] != 0]

round(df3["time"].value_counts()/len(df3)*100, 2)
# Out:
# <ipython-input-109-d484fa9f975e>:7: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# time
# First Half    100.0
# Name: count, dtype: float64

# %%
#Does substitution turns out to be fruitful or not for the team

#factors
# substituted player has scored
# the team score increases after the substitution

# %%
matches_df = pd.read_csv("/content/drive/MyDrive/EDA/matches_1930_2022 - matches_1930_2022.csv.csv")

# %%
def parse_substitution_data(subs):
  if pd.isna(subs):
    return []
  pattern = r"(\d+)&rsquor;\|(.+?)\|for (.+?)(?=\||$)"
  substitutions = re.findall(pattern, subs)
  return [{"minute": int(match[0]),"player_in": match[1], "player_out":match[2]} for match in substitutions]

# %%
matches_df["home_substitutions"] = matches_df["home_substitute_in_long"].apply(parse_substitution_data)
matches_df["away_substitutions"] = matches_df["away_substitute_in_long"].apply(parse_substitution_data)

# %%
 def parse_goal_data(goals):
  if pd.isna(goals):
    return []
  goal_list = goals.split('|')
  parsed_goals = []
  for goal in goal_list:
    parts = goal.split("·")
    if len(parts) == 2:
      try:
        minute = int(parts[1].strip())
        player = parts[0].strip()
        parsed_goals.append({"minute": minute, "player": player})
      except ValueError:
        pass
  return parsed_goals

# %%
matches_df["home_goal"].apply(parse_goal_data)[0]
# Out:
# [{'minute': 36, 'player': 'Ángel Di María'},
#  {'minute': 108, 'player': 'Lionel Messi'}]

# %%
matches_df["home_goal_details"] = matches_df["home_goal"].apply(parse_goal_data)
matches_df["away_goal_details"] = matches_df["away_goal"].apply(parse_goal_data)

# %%
def filter_matches_by_team(df, team):
  return df[(df["home_team"] == team) | (df["away_team"] == team)]

# %%
team_name = "Germany"

team_matches_df = filter_matches_by_team(matches_df, team_name)

# %%
team_matches_df
# Out:
#           home_team            away_team  home_score  home_xg  home_penalty  \
# 22       Costa Rica              Germany           2      1.3           NaN
# 39            Spain              Germany           1      0.6           NaN
# 53          Germany                Japan           1      3.1           NaN
# 84   Korea Republic              Germany           2      1.7           NaN
# 101         Germany               Sweden           2      1.4           NaN
# 118         Germany               Mexico           0      1.4           NaN
# 128         Germany            Argentina           1      NaN           NaN
# 131          Brazil              Germany           1      NaN           NaN
# 134          France              Germany           0      NaN           NaN
# 139         Germany              Algeria           2      NaN           NaN
# 144   United States              Germany           0      NaN           NaN
# ...

# %%
#if substituted player scored a goal
def check_substitute_goals(subs, goals):
  if not subs:
    return False
  for sub in subs:
    if any(goal["player"] == sub["player_in"] for goal in goals):
      return True
  return False




def check_team_substitute_goals(row, team_name):
  if row["home_team"] == team_name:
    return check_substitute_goals(row["home_substitutions"], row["home_goal_details"])
  elif row["away_team"] == team_name:
    return check_substitute_goals(row["away_substitutions"], row["away_goal_details"])
  else:
    return False

# %%
def check_substitution_impact(row, team_name):
  if row["home_team"] == team_name:
    subs = row["home_substitutions"]
    goals_before = [goal for goal in row["home_goal_details"] if subs and goal['minute'] <= subs[0]['minute']] if subs else []
    goals_after = [goal for goal in row["home_goal_details"] if subs and goal['minute'] > subs[0]['minute']] if subs else []

  elif row["away_team"] == team_name:
    subs = row["away_substitutions"]
    goals_before = [goal for goal in row["away_goal_details"] if subs and goal['minute'] <= subs[0]['minute']] if subs else []
    goals_after = [goal for goal in row["away_goal_details"] if subs and goal['minute'] > subs[0]['minute']] if subs else []
  else:
    return False


  return len(goals_after) > len(goals_before)

# %%
team_matches_df['substitution_impact'] = team_matches_df.apply(lambda row: check_substitution_impact(row, team_name), axis=1)
team_matches_df['substitute_goals'] = team_matches_df.apply(lambda row: check_team_substitute_goals(row, team_name), axis=1)
# Out:
# <ipython-input-189-5ebd573eeca9>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-189-5ebd573eeca9>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
match_summaries = []

for index, row in team_matches_df.iterrows():
    match_summary = {
        'Match': f"{row['home_team']} vs {row['away_team']}",
        'Date': row['Date'],
        'Substitute Scored': row['substitute_goals'],
        'Substitution Impact': row['substitution_impact']
    }
    match_summaries.append(match_summary)

# %%
summary_df = pd.DataFrame(match_summaries)

# %%
summary_df
# Out:
#                          Match        Date  Substitute Scored  \
# 0          Argentina vs France  2022-12-18              False
# 1         Argentina vs Croatia  2022-12-13              False
# 2     Netherlands vs Argentina  2022-12-09              False
# 3       Argentina vs Australia  2022-12-03              False
# 4          Poland vs Argentina  2022-11-30              False
# ..                         ...         ...                ...
# 83        Uruguay vs Argentina  1930-07-30              False
# 84  Argentina vs United States  1930-07-26              False
# 85          Argentina vs Chile  1930-07-22              False
# 86         Argentina vs Mexico  1930-07-19              False
# 87         Argentina vs France  1930-07-15              False
#
#     Substitution Impact
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 83                False
# ...

# %%
print(summary_df['Substitute Scored'].value_counts())
print('***')
print(summary_df['Substitution Impact'].value_counts())
# Out:
# Substitute Scored
# False    88
# Name: count, dtype: int64
# ***
# Substitution Impact
# False    69
# True     19
# Name: count, dtype: int64

# %%
#Team expected performance and actual performance

# %%
home_team_stats = matches.groupby(['home_team','Year']).agg({
    'home_score': 'sum',
    'home_xg':'sum',
}).rename(columns={'home_score':'Total_goals'})


away_team_stats = matches.groupby(['away_team','Year']).agg({
    'away_score': 'sum',
    'away_xg':'sum',
}).rename(columns={'away_score':'Total_goals'})

# %%
home_team_stats.reset_index(inplace=True)
away_team_stats.reset_index(inplace=True)

# %%
home_team_stats
# Out:
#       home_team  Year  Total_goals  home_xg
# 0       Algeria  1982            3      0.0
# 1       Algeria  1986            1      0.0
# 2       Algeria  2010            0      0.0
# 3       Algeria  2014            1      0.0
# 4        Angola  2006            0      0.0
# ..          ...   ...          ...      ...
# 424  Yugoslavia  1962            9      0.0
# 425  Yugoslavia  1974            9      0.0
# 426  Yugoslavia  1982            0      0.0
# 427  Yugoslavia  1990            5      0.0
# 428       Zaire  1974            0      0.0
#
# [429 rows x 4 columns]

# %%
home_team_stats= home_team_stats[(home_team_stats['Year']==2018 )|(home_team_stats['Year']==2022)]
away_team_stats= away_team_stats[(away_team_stats['Year']==2018 )|(away_team_stats['Year']==2022)]

# %%
home_team_stats
# Out:
#          home_team  Year  Total_goals  home_xg
# 20       Argentina  2018            1      3.2
# 21       Argentina  2022           11      9.7
# 26       Australia  2018            0      0.9
# 27       Australia  2022            1      0.6
# 41         Belgium  2018           13     11.2
# ..             ...   ...          ...      ...
# 380        Tunisia  2022            1      1.4
# 394  United States  2022            1      0.8
# 407        Uruguay  2018            6      5.6
# 408        Uruguay  2022            0      0.6
# 410          Wales  2022            0      1.2
#
# [64 rows x 4 columns]

# %%
home_team_stats.rename(columns= {'home_team':'team'}, inplace=True)
away_team_stats.rename(columns= {'away_team':'team'}, inplace=True)
# Out:
# <ipython-input-234-27024e747301>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged = pd.merge(home_team_stats, away_team_stats, on=['team','Year'], how='outer')

# %%
merged
# Out:
#              team  Year  Total_goals_x  home_xg  Total_goals_y  away_xg
# 0       Argentina  2018              1      3.2              5      1.7
# 1       Argentina  2022             11      9.7              4      5.4
# 2       Australia  2018              0      0.9              2      2.3
# 3       Australia  2022              1      0.6              3      1.7
# 4         Belgium  2018             13     11.2              3      2.2
# ..            ...   ...            ...      ...            ...      ...
# 59        Tunisia  2022              1      1.4              0      0.9
# 60  United States  2022              1      0.8              2      3.3
# 61        Uruguay  2018              6      5.6              1      1.6
# 62        Uruguay  2022              0      0.6              2      3.1
# 63          Wales  2022              0      1.2              1      1.5
#
# [64 rows x 6 columns]

# %%
merged['Total_goals']= merged['Total_goals_x']+merged['Total_goals_y']
merged['Total_xg']= merged['home_xg']+merged['away_xg']
merged['Deviation']=merged['Total_xg']-merged['Total_goals']

# %%
merged[merged['Year']==2022]
# Out:
#               team  Year  Total_goals_x  home_xg  Total_goals_y  away_xg  \
# 1        Argentina  2022             11      9.7              4      5.4
# 3        Australia  2022              1      0.6              3      1.7
# 5          Belgium  2022              1      1.8              0      3.0
# 7           Brazil  2022              7      7.0              1      5.0
# 8         Cameroon  2022              4      2.7              0      0.7
# 9           Canada  2022              1      1.4              1      2.8
# 12      Costa Rica  2022              2      1.3              1      0.1
# 14         Croatia  2022              7      4.6              1      2.4
# 16         Denmark  2022              0      1.4              1      1.2
# 17         Ecuador  2022              1      0.9              3      2.9
# 20         England  2022             10      6.3              3      2.4
# 22          France  2022             11      9.8              5      3.9
# ...
